# %% [markdown]
# # Exp1

# %%
# Questo è stato fatto con il dataset non ridotto.
# !python train.py \
--exp=1 \
--weights=imagenet \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000 \
--cache_train=False \
--cache_val=False
# Out:
# 2020-04-26 11:04:33.092504: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-04-26 11:04:33.116468: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200070000 Hz
# 2020-04-26 11:04:33.116848: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55dc684150e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-26 11:04:33.116875: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-26 11:04:33.116985: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 462 steps, validate for 151 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp2

# %%
# Da qua in poi ho usato il dataset ridotto
# !python train.py \
--exp=2 \
--weights=imagenet \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-04-30 17:12:55.919619: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-04-30 17:12:55.943301: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3199790000 Hz
# 2020-04-30 17:12:55.943618: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56215cdd5960 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-30 17:12:55.943710: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-30 17:12:55.943821: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ...
# 83689472/83683744 [==============================] - 20s 0us/step
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 3

# %%
# Ho provato senza data augmentation ma è aumentato l'overfitting.
# !python train.py \
--exp=3 \
--weights=imagenet \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000 \
--random_flip=False \
--random_hue=False \
--random_saturation=False \
--random_contrast=False \
--random_brightness=False
# Out:
# 2020-04-30 17:46:39.025656: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-04-30 17:46:39.059332: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3199790000 Hz
# 2020-04-30 17:46:39.059979: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55bd8176f2a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-30 17:46:39.060006: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-30 17:46:39.060419: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 4

# %%
# Proviamo con la dimensione fissa, risultati leggermente migliori.
# !python train.py \
--exp=4 \
--size=299 \
--weights=imagenet \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-04-30 18:05:32.735607: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-04-30 18:05:32.763279: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3199790000 Hz
# 2020-04-30 18:05:32.763549: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55abbecdd5e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-04-30 18:05:32.763568: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-04-30 18:05:32.763657: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 5

# %%
# Proviamo a riaddestrare anche il penultimo layer
# !python train.py \
--exp=5 \
--weights="checkpoints/exp2/best_weights.ckpt" \
--trainable_layers=5 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 09:40:55.845672: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 09:40:55.868843: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 09:40:55.869184: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55aa45e79800 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 09:40:55.869210: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 09:40:55.869325: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# block14_sepconv2
# block14_sepconv2_bn
# block14_sepconv2_act
# global_average_pooling2d
# output
# ...

# %% [markdown]
# # Exp 6

# %%
# Proviamo a riaddestrare anche il terzultimo layer
# !python train.py \
--exp=6 \
--weights="checkpoints/exp5/best_weights.ckpt" \
--trainable_layers=8 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 10:07:48.857835: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 10:07:48.884725: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 10:07:48.885024: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5619d6905800 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 10:07:48.885050: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 10:07:48.885173: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# block14_sepconv1
# block14_sepconv1_bn
# block14_sepconv1_act
# block14_sepconv2
# block14_sepconv2_bn
# block14_sepconv2_act
# ...

# %%
# Proviamo a valutare sul test set (forse stimavo male i valori?)
# !python test.py \
--weights="checkpoints/exp6/best_weights.ckpt" \
--optimizer="nadam"
# Out:
# 2020-05-01 12:05:00.441049: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 12:05:00.464840: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 12:05:00.465183: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556898cab460 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 12:05:00.465209: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 12:05:00.465344: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ...

# %% [markdown]
# # Exp 7

# %%
# Riproviamo l'exp 2 ma shufflando anche il validation set (forse stimavo male i valori?)
# !python train.py \
--exp=7 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 10:49:57.278551: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 10:49:57.300782: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 10:49:57.301112: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f061fd4810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 10:49:57.301151: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 10:49:57.301273: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 8

# %%
# Riproviamo l'exp 2 ma con un'epoca vera sul validation set (forse stimavo male i valori?)
# !python train.py \
--exp=8 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 10:58:58.135138: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 10:58:58.160782: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 10:58:58.161105: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5561b6f5c810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 10:58:58.161133: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 10:58:58.161246: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 451 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 9

# %%
# Riproviamo l'exp 2 ma con batch_size 1 sul validation set (forse stimavo male i valori?)
# !python train.py \
--exp=9 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 11:46:27.459380: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 11:46:27.484790: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 11:46:27.485080: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5587020c8810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 11:46:27.485117: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 11:46:27.485242: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 180 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 10

# %%
# Riproviamo l'exp 2 ma con un'epoca vera sul training e validation set (forse stimavo male i valori?)
# !python train.py \
--exp=10 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 12:07:27.710018: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 12:07:27.732847: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 12:07:27.733195: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c129bf2810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 12:07:27.733221: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 12:07:27.733337: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 3682 steps, validate for 451 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 11

# %%
# Riproviamo l'exp 2 ma con un buffer di shuffle più grande (forse stimavo male i valori?)
# !python train.py \
--exp=11 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 13:05:08.596123: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 13:05:08.628763: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 13:05:08.629712: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x555e85622810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 13:05:08.629743: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 13:05:08.630656: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 12

# %%
# Riproviamo l'exp 2 ma senza cache del dataset (forse stimavo male i valori?)
# !python train.py \
--exp=12 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000 \
--cache_train=False \
--cache_val=False
# Out:
# 2020-05-01 13:23:59.788390: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 13:23:59.824786: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 13:23:59.825562: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56289795d030 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 13:23:59.825606: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 13:23:59.826049: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 13

# %%
# Riproviamo l'exp 2 ma disabilitando la data augmentation (forse stimavo male i valori?)
# !python train.py \
--exp=13 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 13:32:20.763056: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 13:32:20.792819: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 13:32:20.793185: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x555c4a496810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 13:32:20.793203: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 13:32:20.793293: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %% [markdown]
# # Exp 14

# %%
# Riproviamo l'exp 2 ma con resnet50 (overfitting?)
# !python train.py \
--exp=14 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 13:55:15.927171: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 13:55:15.952728: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 13:55:15.953003: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fba9feb810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 13:55:15.953025: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 13:55:15.953122: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ...
# 94773248/94765736 [==============================] - 23s 0us/step
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %%
# Riproviamo l'exp 2 ma con mobilenet (overfitting?)
# !python train.py \
--exp=15 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 13:59:49.747595: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 13:59:49.772762: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 13:59:49.773083: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5591c808a810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 13:59:49.773108: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 13:59:49.773225: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ...

# %%
# Riproviamo l'exp 2 ma con sgd (overfitting?)
# !python train.py \
--exp=16 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="sgd" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-01 14:08:20.724937: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-01 14:08:20.758047: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200090000 Hz
# 2020-05-01 14:08:20.758319: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55cc79b68810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-01 14:08:20.758338: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-01 14:08:20.758419: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# output
# Train for 184 steps, validate for 22 steps
# Epoch 1/1000
# ...

# %%
# Riproviamo l'exp 2 ma con unfreeze di batch normalization (overfitting?)
# !python train.py \
--exp=17 \
--weights="imagenet" \
--trainable_layers=1 \
--optimizer="nadam" \
--batch_size=8 \
--epochs=1000
# Out:
# 2020-05-02 20:43:07.404856: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2020-05-02 20:43:07.440390: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3200120000 Hz
# 2020-05-02 20:43:07.441028: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55cabd44b810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-02 20:43:07.441056: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-02 20:43:07.442199: I tensorflow/core/common_runtime/process_util.cc:147] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Trainable layers:
# block1_conv1_bn
# block1_conv2_bn
# block2_sepconv1_bn
# block2_sepconv2_bn
# batch_normalization
# block3_sepconv1_bn
# ...
